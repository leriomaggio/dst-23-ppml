# %%
# !pip install notexbook-theme
# Out:
# Requirement already satisfied: notexbook-theme in /Users/leriomaggio/anaconda3/envs/torch-arm/lib/python3.10/site-packages (2.0.1)
# Requirement already satisfied: ipython>=7.0 in /Users/leriomaggio/anaconda3/envs/torch-arm/lib/python3.10/site-packages (from notexbook-theme) (8.4.0)
# Requirement already satisfied: jupyter in /Users/leriomaggio/anaconda3/envs/torch-arm/lib/python3.10/site-packages (from notexbook-theme) (1.0.0)
# Requirement already satisfied: jinja2 in /Users/leriomaggio/anaconda3/envs/torch-arm/lib/python3.10/site-packages (from notexbook-theme) (3.0.3)
# Requirement already satisfied: notebook in /Users/leriomaggio/anaconda3/envs/torch-arm/lib/python3.10/site-packages (from notexbook-theme) (6.4.12)
# Requirement already satisfied: traitlets>=5 in /Users/leriomaggio/anaconda3/envs/torch-arm/lib/python3.10/site-packages (from ipython>=7.0->notexbook-theme) (5.1.1)
# Requirement already satisfied: matplotlib-inline in /Users/leriomaggio/anaconda3/envs/torch-arm/lib/python3.10/site-packages (from ipython>=7.0->notexbook-theme) (0.1.6)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/leriomaggio/anaconda3/envs/torch-arm/lib/python3.10/site-packages (from ipython>=7.0->notexbook-theme) (3.0.20)
# Requirement already satisfied: appnope in /Users/leriomaggio/anaconda3/envs/torch-arm/lib/python3.10/site-packages (from ipython>=7.0->notexbook-theme) (0.1.2)
# Requirement already satisfied: setuptools>=18.5 in /Users/leriomaggio/anaconda3/envs/torch-arm/lib/python3.10/site-packages (from ipython>=7.0->notexbook-theme) (63.4.1)
# Requirement already satisfied: pexpect>4.3 in /Users/leriomaggio/anaconda3/envs/torch-arm/lib/python3.10/site-packages (from ipython>=7.0->notexbook-theme) (4.8.0)
# Requirement already satisfied: backcall in /Users/leriomaggio/anaconda3/envs/torch-arm/lib/python3.10/site-packages (from ipython>=7.0->notexbook-theme) (0.2.0)
# Requirement already satisfied: pygments>=2.4.0 in /Users/leriomaggio/anaconda3/envs/torch-arm/lib/python3.10/site-packages (from ipython>=7.0->notexbook-theme) (2.11.2)
# Requirement already satisfied: jedi>=0.16 in /Users/leriomaggio/anaconda3/envs/torch-arm/lib/python3.10/site-packages (from ipython>=7.0->notexbook-theme) (0.18.1)
# Requirement already satisfied: decorator in /Users/leriomaggio/anaconda3/envs/torch-arm/lib/python3.10/site-packages (from ipython>=7.0->notexbook-theme) (5.1.1)
# Requirement already satisfied: stack-data in /Users/leriomaggio/anaconda3/envs/torch-arm/lib/python3.10/site-packages (from ipython>=7.0->notexbook-theme) (0.2.0)
# Requirement already satisfied: pickleshare in /Users/leriomaggio/anaconda3/envs/torch-arm/lib/python3.10/site-packages (from ipython>=7.0->notexbook-theme) (0.7.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/leriomaggio/anaconda3/envs/torch-arm/lib/python3.10/site-packages (from jinja2->notexbook-theme) (2.1.1)
# Requirement already satisfied: jupyter-console in /Users/leriomaggio/anaconda3/envs/torch-arm/lib/python3.10/site-packages (from jupyter->notexbook-theme) (6.4.3)
# Requirement already satisfied: qtconsole in /Users/leriomaggio/anaconda3/envs/torch-arm/lib/python3.10/site-packages (from jupyter->notexbook-theme) (5.3.2)
# Requirement already satisfied: ipywidgets in /Users/leriomaggio/anaconda3/envs/torch-arm/lib/python3.10/site-packages (from jupyter->notexbook-theme) (7.6.5)
# Requirement already satisfied: ipykernel in /Users/leriomaggio/anaconda3/envs/torch-arm/lib/python3.10/site-packages (from jupyter->notexbook-theme) (6.15.2)
# Requirement already satisfied: nbconvert in /Users/leriomaggio/anaconda3/envs/torch-arm/lib/python3.10/site-packages (from jupyter->notexbook-theme) (6.4.4)
# Requirement already satisfied: pyzmq>=17 in /Users/leriomaggio/anaconda3/envs/torch-arm/lib/python3.10/site-packages (from notebook->notexbook-theme) (23.2.0)
# Requirement already satisfied: jupyter-client>=5.3.4 in /Users/leriomaggio/anaconda3/envs/torch-arm/lib/python3.10/site-packages (from notebook->notexbook-theme) (7.3.5)
# Requirement already satisfied: ipython-genutils in /Users/leriomaggio/anaconda3/envs/torch-arm/lib/python3.10/site-packages (from notebook->notexbook-theme) (0.2.0)
# Requirement already satisfied: jupyter-core>=4.6.1 in /Users/leriomaggio/anaconda3/envs/torch-arm/lib/python3.10/site-packages (from notebook->notexbook-theme) (4.11.1)
# Requirement already satisfied: Send2Trash>=1.8.0 in /Users/leriomaggio/anaconda3/envs/torch-arm/lib/python3.10/site-packages (from notebook->notexbook-theme) (1.8.0)
# Requirement already satisfied: nest-asyncio>=1.5 in /Users/leriomaggio/anaconda3/envs/torch-arm/lib/python3.10/site-packages (from notebook->notexbook-theme) (1.5.5)
# Requirement already satisfied: terminado>=0.8.3 in /Users/leriomaggio/anaconda3/envs/torch-arm/lib/python3.10/site-packages (from notebook->notexbook-theme) (0.13.1)
# Requirement already satisfied: prometheus-client in /Users/leriomaggio/anaconda3/envs/torch-arm/lib/python3.10/site-packages (from notebook->notexbook-theme) (0.14.1)
# Requirement already satisfied: argon2-cffi in /Users/leriomaggio/anaconda3/envs/torch-arm/lib/python3.10/site-packages (from notebook->notexbook-theme) (21.3.0)
# Requirement already satisfied: nbformat in /Users/leriomaggio/anaconda3/envs/torch-arm/lib/python3.10/site-packages (from notebook->notexbook-theme) (5.5.0)
# Requirement already satisfied: tornado>=6.1 in /Users/leriomaggio/anaconda3/envs/torch-arm/lib/python3.10/site-packages (from notebook->notexbook-theme) (6.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/leriomaggio/anaconda3/envs/torch-arm/lib/python3.10/site-packages (from jedi>=0.16->ipython>=7.0->notexbook-theme) (0.8.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/leriomaggio/anaconda3/envs/torch-arm/lib/python3.10/site-packages (from jupyter-client>=5.3.4->notebook->notexbook-theme) (2.8.2)
# Requirement already satisfied: entrypoints in /Users/leriomaggio/anaconda3/envs/torch-arm/lib/python3.10/site-packages (from jupyter-client>=5.3.4->notebook->notexbook-theme) (0.4)
# Requirement already satisfied: bleach in /Users/leriomaggio/anaconda3/envs/torch-arm/lib/python3.10/site-packages (from nbconvert->jupyter->notexbook-theme) (4.1.0)
# Requirement already satisfied: testpath in /Users/leriomaggio/anaconda3/envs/torch-arm/lib/python3.10/site-packages (from nbconvert->jupyter->notexbook-theme) (0.6.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /Users/leriomaggio/anaconda3/envs/torch-arm/lib/python3.10/site-packages (from nbconvert->jupyter->notexbook-theme) (0.8.4)
# Requirement already satisfied: beautifulsoup4 in /Users/leriomaggio/anaconda3/envs/torch-arm/lib/python3.10/site-packages (from nbconvert->jupyter->notexbook-theme) (4.11.1)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /Users/leriomaggio/anaconda3/envs/torch-arm/lib/python3.10/site-packages (from nbconvert->jupyter->notexbook-theme) (0.5.13)
# Requirement already satisfied: jupyterlab-pygments in /Users/leriomaggio/anaconda3/envs/torch-arm/lib/python3.10/site-packages (from nbconvert->jupyter->notexbook-theme) (0.1.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/leriomaggio/anaconda3/envs/torch-arm/lib/python3.10/site-packages (from nbconvert->jupyter->notexbook-theme) (1.5.0)
# Requirement already satisfied: defusedxml in /Users/leriomaggio/anaconda3/envs/torch-arm/lib/python3.10/site-packages (from nbconvert->jupyter->notexbook-theme) (0.7.1)
# Requirement already satisfied: jsonschema>=2.6 in /Users/leriomaggio/anaconda3/envs/torch-arm/lib/python3.10/site-packages (from nbformat->notebook->notexbook-theme) (4.16.0)
# Requirement already satisfied: fastjsonschema in /Users/leriomaggio/anaconda3/envs/torch-arm/lib/python3.10/site-packages (from nbformat->notebook->notexbook-theme) (2.16.2)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/leriomaggio/anaconda3/envs/torch-arm/lib/python3.10/site-packages (from pexpect>4.3->ipython>=7.0->notexbook-theme) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/leriomaggio/anaconda3/envs/torch-arm/lib/python3.10/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7.0->notexbook-theme) (0.2.5)
# Requirement already satisfied: argon2-cffi-bindings in /Users/leriomaggio/anaconda3/envs/torch-arm/lib/python3.10/site-packages (from argon2-cffi->notebook->notexbook-theme) (21.2.0)
# Requirement already satisfied: debugpy>=1.0 in /Users/leriomaggio/anaconda3/envs/torch-arm/lib/python3.10/site-packages (from ipykernel->jupyter->notexbook-theme) (1.5.1)
# Requirement already satisfied: packaging in /Users/leriomaggio/anaconda3/envs/torch-arm/lib/python3.10/site-packages (from ipykernel->jupyter->notexbook-theme) (21.3)
# Requirement already satisfied: psutil in /Users/leriomaggio/anaconda3/envs/torch-arm/lib/python3.10/site-packages (from ipykernel->jupyter->notexbook-theme) (5.9.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /Users/leriomaggio/anaconda3/envs/torch-arm/lib/python3.10/site-packages (from ipywidgets->jupyter->notexbook-theme) (1.0.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /Users/leriomaggio/anaconda3/envs/torch-arm/lib/python3.10/site-packages (from ipywidgets->jupyter->notexbook-theme) (3.5.2)
# Requirement already satisfied: qtpy>=2.0.1 in /Users/leriomaggio/anaconda3/envs/torch-arm/lib/python3.10/site-packages (from qtconsole->jupyter->notexbook-theme) (2.2.0)
# Requirement already satisfied: executing in /Users/leriomaggio/anaconda3/envs/torch-arm/lib/python3.10/site-packages (from stack-data->ipython>=7.0->notexbook-theme) (0.8.3)
# Requirement already satisfied: asttokens in /Users/leriomaggio/anaconda3/envs/torch-arm/lib/python3.10/site-packages (from stack-data->ipython>=7.0->notexbook-theme) (2.0.5)
# Requirement already satisfied: pure-eval in /Users/leriomaggio/anaconda3/envs/torch-arm/lib/python3.10/site-packages (from stack-data->ipython>=7.0->notexbook-theme) (0.2.2)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/leriomaggio/anaconda3/envs/torch-arm/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat->notebook->notexbook-theme) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in /Users/leriomaggio/anaconda3/envs/torch-arm/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat->notebook->notexbook-theme) (21.4.0)
# Requirement already satisfied: six>=1.5 in /Users/leriomaggio/anaconda3/envs/torch-arm/lib/python3.10/site-packages (from python-dateutil>=2.8.2->jupyter-client>=5.3.4->notebook->notexbook-theme) (1.16.0)
# Requirement already satisfied: cffi>=1.0.1 in /Users/leriomaggio/anaconda3/envs/torch-arm/lib/python3.10/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook->notexbook-theme) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in /Users/leriomaggio/anaconda3/envs/torch-arm/lib/python3.10/site-packages (from beautifulsoup4->nbconvert->jupyter->notexbook-theme) (2.3.2.post1)
# Requirement already satisfied: webencodings in /Users/leriomaggio/anaconda3/envs/torch-arm/lib/python3.10/site-packages (from bleach->nbconvert->jupyter->notexbook-theme) (0.5.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/leriomaggio/anaconda3/envs/torch-arm/lib/python3.10/site-packages (from packaging->ipykernel->jupyter->notexbook-theme) (3.0.9)
# Requirement already satisfied: pycparser in /Users/leriomaggio/anaconda3/envs/torch-arm/lib/python3.10/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->notexbook-theme) (2.21)

# %%
# %load_ext notexbook

# %%
# %texify -fs 18
# Out:
# <style type="text/css">
#     /*
# Author: Valerio Maggio < @leriomaggio >
# Code: https://github.com/leriomaggio/notexbook-jupyter-theme
# License: Apache License 2.0
# */
#
# /*
# Author: Valerio Maggio < @leriomaggio >
# Code: https://github.com/leriomaggio/notexbook-jupyter-theme
# License: Apache License 2.0
#
#  ======================================================
#                          FONTS
#
#     FONT WEIGHT MAP:
#     ----------------
#     100: Ultra Light
#     200: Thin
#     300: Light
#     400: Regular (normal)
#     500: Medium
#     600: Semi-bold
#     700: Bold
#     800: Heavy
#     900: Black
#
#     Font faces:
#         - ====================================|=======================
#         -              Scope                  | Font Family Name
#         - ====================================| ======================
#         - Markdown Display (Computer Modern)    (CMU Serif)
#         - Markdown Display monospace            (CMU Typewriter Text)
#         - Markdown Edit    monospace            (Hack)
#         - Source Code      monospace            (Fira Code)
#         - ====================================| =======================
#
#  ======================================================  */
#
# /* Roboto Slab */
# @import url("https://fonts.googleapis.com/css2?family=Roboto+Slab:wght@100;200;300;400;500;600;700;800;900&display=swap");
# /*md-display-computer-modern --> CMU Serif*/
# @import url("https://fonts.cdnfonts.com/css/cmu-serif?styles=30038,30039,30037,30036");
# /*md-display-monospace --> CMU Typewriter Text*/
# @import url("https://fonts.cdnfonts.com/css/cmu-typewriter-text?styles=24833,24829,24830,24831,24832,24834");
# /*code-monospace --> Fira Code*/
# @import url("https://fonts.googleapis.com/css2?family=Fira+Code:wght@300;400;500&display=swap");
# /*md-edit-monospace --> Hack*/
# @import url("https://fonts.cdnfonts.com/css/hack?styles=20708,20707,20705,20706");
# /*
# Author: Valerio Maggio < @leriomaggio >
# Code: https://github.com/leriomaggio/notexbook-jupyter-theme
# License: Apache License 2.0
#
# ======================================================
#
#
#     ---------------------------------
#     Code Mirror - Code Cell Highlight
#     ---------------------------------
#
#     Define the Style for Code **and** Markdown editors (Themes)
#     Theme files are all located in the "themes" folder, and the
#     different styles for the Code and Markdown editors are
#     distinguished by a common prefix in the file names:
#
#         --> Code editors Themes: "themes/code_*"
#         --> Markdown Editor Themes: "themes/md_*"
#
#     Styles can be imported as separate CSS modules.
#
#     Current stylesheet (editor.css) defines the CSS rules
#     for notebook tags and classes. These rules are
#     all based to colors defined in external Theme files.
#
#     This would ease the definition of other custom CSS Editor themes
# */
#
# /* Code Editor theme */
#
#     /*
# Author: Valerio Maggio < @leriomaggio >
# Code: https://github.com/leriomaggio/notexbook-jupyter-theme
# License: Apache License 2.0
#
#  ======================================================
#
# The color palette is inspired by Light
#  Material Design theme
# Repo: https://github.com/JonaDuran/Material-Light-Theme/
# */
#
# :root {
#     /* Color Palette */
#     --ml-white: #ffffff;
#     --ml-light-white: #FAFAFA;
#     --ml-black: #24292E;
#     --ml-dark-blue : #01579B11;
#     --ml-dark-blue-2: #01579B22;
#     --ml-blue: #1565C0;
#     --ml-green: #2E7D32;
#     --ml-yellow: #A8601A;
#     --ml-cyan: #00838f;
#     --ml-magenta: #9C00B0;
#     --ml-red: #C0392B;
#     --ml-grey: #9E9E9E;
#     --ml-light-blue: #78909c;
#
#
#     /* Editor Theme */
#     --code-background-color: var(--ml-light-white);
#     --gutter-background: var(--ml-light-white);
#     --selection-background-color: var(--ml-dark-blue-2);
#     --line-numbers: var(--ml-grey);
#     --cursor: var(--ml-black);
#     --bracket: var(--ml-black);
#     --matching-bracket: var(--ml-blue);
#     --code-text-color: var(--ml-black);
#     --keywords: var(--ml-magenta);
#     --types: var(--ml-magenta);
#     --variables: var(--code-text-color);
#     --variables2: var(--ml-green);
#     --def: var(--ml-blue);
#     --property: var(--ml-blue);
#     --meta: var(--ml-light-blue);
#     --builtin: var(--ml-blue);
#     --attribute: var(--ml-blue);
#     --strings: var(--ml-yellow);
#     --strings2: var(--ml-grey);
#     --comments: var(--ml-grey);
#     --operator: var(--ml-magenta);
#     --numbers: var(--ml-red);
#     /* Dataframe */
#     --dataframe: var(--code-text-color);
#     --df-bg: var(--ml-light-white);
#     --df-thead: var(--ml-blue);
#     --df-thead-border: var(--ml-black);
#     --df-tr-hover: var(--selection-background-color);
#     --df-border: var(--ml-white);
#     --df-border-right: var(--ml-grey);
#     --df-th-bg: var(--ml-white);
#     /*ANSI Colours*/
#     --ansi-red: var(--ml-red);
#     --ansi-green: var(--ml-green);
#     --ansi-green-intense: var(--ml-grey);
#     --ansi-cyan: var(--ml-cyan);
#     --ansi-blue: var(--ml-blue);
# }
#
#
#
# /* Markdown Editor theme */
#
#     /*
# Author: Valerio Maggio < @leriomaggio >
# Code: https://github.com/leriomaggio/notexbook-jupyter-theme
# License: Apache License 2.0
#
#  ======================================================
#
#     Custom Theme for Markdown Editor
#     based on Material Clear Theme.
#
#  */
#
# :root {
#     /* Color Palette */
#     --md-ml-red: #C0392B;
#     --md-ml-yellow: #A8601A;
#     --md-ml-black: #24292E;
#     --md-ml-grey: #9E9E9E;
#     --md-ml-blue: #1565C0;
#     --md-ml-dark-blue: #01579B;
#     --md-ml-light-blue: #78909c;
#
#     /*  Editor Theme  */
#     --editor-text: var(--md-ml-black);
#     --header: var(--md-ml-dark-blue);
#     --quote: var(--md-ml-grey);
#     --link: var(--md-ml-blue);
#     --attribute: var(--md-ml-red);
#     --tag: var(--md-ml-yellow);
#     --string: var(--md-ml-yellow);
#     --delimiter: var(--md-ml-black);
#     --monospace: var(--md-ml-light-blue);
# }
#
#
#
#
#
#
#
# /*
# Author: Valerio Maggio < @leriomaggio >
# Code: https://github.com/leriomaggio/notexbook-jupyter-theme
# License: Apache License 2.0
# */
#
# /*
#     =================
#     Code Editor Theme
#     =================
# */
# div.output_error pre,
# div.output_result pre,
# div.output_stream pre {
#     color: var(--code-text-color) !important;
# }
#
# .cm-s-ipython.CodeMirror,
# .cm-s-jupyter.CodeMirror {
#     background: var(--code-background-color);
#     color: var(--code-text-color);
# }
#
# .cm-s-ipython div.CodeMirror-selected,
# .cm-s-jupyter div.CodeMirror-selected {
#     cursor: pointer;
#     background: var(--selection-background-color);
# }
#
# .cm-s-ipython .CodeMirror-gutters,
# .cm-s-jupyter .CodeMirror-gutters {
#     background: var(--gutter-background);
#     border-right: 0;
# }
#
# .cm-s-ipython .CodeMirror-linenumber,
# .cm-s-jupyter .CodeMirror-linenumber {
#     color: var(--line-numbers);
# }
#
# .cm-s-ipython .CodeMirror-cursor,
# .cm-s-jupyter .CodeMirror-cursor {
#     border-left: 1px solid var(--cursor) !important;
# }
#
# .cm-s-ipython span.cm-bracket,
# .cm-s-jupyter span.cm-bracket {
#     /*color: #828282;*/
#     color: var(--bracket);
# }
#
# span.CodeMirror-matchingbracket {
#     text-decoration: underline !important;
#     text-decoration-color: var(--matching-bracket) !important;
#     color: var(--matching-bracket) !important;
# }
#
# .cm-s-ipython span.cm-keyword,
# .cm-s-jupyter span.cm-keyword {
#     color: var(--keywords);
#     font-weight: 400;
# }
#
# .cm-s-ipython span.cm-variable,
# .cm-s-jupyter span.cm-variable {
#     color: var(--variables);
# }
#
# .cm-s-ipython span.cm-variable-2,
# .cm-s-jupyter span.cm-variable-2 {
#     color: var(--variables2);
# }
#
# .cm-s-ipython span.cm-def,
# .cm-s-jupyter span.cm-def {
#     color: var(--def);
# }
#
# .cm-s-ipython span.cm-property,
# .cm-s-jupyter span.cm-property {
#     color: var(--property);
# }
#
# .cm-s-ipython span.cm-meta,
# .cm-s-jupyter span.cm-meta {
#     color: var(--meta);
# }
#
# .cm-s-ipython span.cm-attribute,
# .cm-s-jupyter span.cm-attribute {
#     color: var(--attribute);
# }
#
# .cm-s-ipython span.cm-builtin,
# .cm-s-jupyter span.cm-builtin {
#     color: var(--builtin)
# }
#
# .cm-s-ipython span.cm-string,
# .cm-s-jupyter span.cm-string {
#     color: var(--strings);
# }
#
# .cm-s-ipython span.cm-string-2,
# .cm-s-jupyter span.cm-string-2 {
#     color

# %% [markdown]
# # Preamble
#
# The material for this section has been **adapted** from the wonderful (online) book entitled **Programming Differential Privacy**, _Differential privacy, for programmers_.
#
# The book is intended to give you an introduction to the challenges of data privacy, introducing the techniques that have been developed for addressing those challenges, and help you understand how to implement some of those techniques.
#
# (from _Introdution_ Chapter):
#
# > This book assumes a working knowledge of Python, as well as basic knowledge of the `pandas` and NumPy libraries.
# > You will also benefit from some background in discrete mathematics and probability - a basic undergraduate course in these topics should be more than sufficient.

# %% [markdown]
# **Source**:
#
# - (HTML Version): [programming-dp.com](https://programming-dp.com)
# - (GitHub): [github.com/uvm-plaid/programming-dp](https://github.com/uvm-plaid/programming-dp)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patheffects as path_effects
plt.style.use('seaborn-whitegrid')
# Out:
# /var/folders/9t/6_5rmqxj7_sc94130gpv4p2h0000gp/T/ipykernel_4044/1159262666.py:5: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-whitegrid')

# %%
ys1 = [np.random.laplace(loc=0, scale=1) for _ in range(10000)]
ys2 = [np.random.laplace(loc=1, scale=1) for _ in range(10000)]

# %%
import matplotlib
f = matplotlib.font_manager.FontProperties(family='Roboto', weight='bold')

# %%
plt.figure(figsize=(15, 4), dpi=80)
_, bins, _ = plt.hist(ys1, bins=100, color='#66AC47',
                     path_effects=[path_effects.withSimplePatchShadow(alpha=.1, offset=(1,-1))])

plt.hist(ys2, bins=bins, alpha=.7, color='#A7D4EE',
        path_effects=[path_effects.withSimplePatchShadow(alpha=.1, offset=(1,-1))])

plt.axis('off');
plt.grid('off');

plt.text(-2.6, -220, 'Programming', fontproperties=f, fontsize=24, 
         color='#007155', 
         path_effects=[path_effects.withSimplePatchShadow(offset=(1, -1), alpha=.1)])

plt.text(0.4, -220, 'Differential Privacy', fontproperties=f, fontsize=24, color='#66AC47',
         path_effects=[path_effects.withSimplePatchShadow(offset=(1, -1), alpha=.1)])

plt.tight_layout()

# %% [markdown]
# ## Data privacy
#
# > **Definition**
# > *Data privacy* techniques have the goal of allowing analysts to learn about *trends* in
# > sensitive data, without revealing information specific to *individuals*.
#
# This is a broad definition, and many different techniques fall under it.
#
# But it's important to note what this definition *excludes*: techniques for ensuring *security*, like encryption.
#
# Encrypted data doesn't reveal *anything* - so it fails to meet the first requirement of our definition.
#
# The distinction between **security** and **privacy** is an important one:
#
# - **Privacy** techniques involve an *intentional* release of information, and attempt to control *what can be learned* from that release;
#
# - **Security** techniques usually *prevent* the release of information, and control *who can access* data.
